# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Train and Test Data

# %%
train_df=pd.read_csv(r"C:\Users\mraj7\Desktop\AI_ML_Projeccts\House_Prices\Data\house-prices-advanced-regression-techniques\train.csv")

# %%
test_df=pd.read_csv(r"C:\Users\mraj7\Desktop\AI_ML_Projeccts\House_Prices\Data\house-prices-advanced-regression-techniques\test.csv")

# %% [markdown]
# ## Checking the FIrst 5 Row of Data

# %%
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ## Checking the Shape of the data

# %%
train_df.shape
# Out:
# (1460, 81)

# %% [markdown]
# ## Data_Types
# ### This Section will get you the information of the datatypes of the column/feature

# %%
train_df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning             str
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType             str
# SaleCondition        str
# SalePrice          int64
# Length: 81, dtype: object

# %% [markdown]
# ## Information of the data
# ### This section will provide you the non null count and dtypes for the columns/features.

# %%
train_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   str
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   str
#  6   Alley          91 non-null     str
#  7   LotShape       1460 non-null   str
#  8   LandContour    1460 non-null   str
#  9   Utilities      1460 non-null   str
#  10  LotConfig      1460 non-null   str
#  11  LandSlope      1460 non-null   str
#  12  Neighborhood   1460 non-null   str
#  13  Condition1     1460 non-null   str
#  14  Condition2     1460 non-null   str
#  15  BldgType       1460 non-null   str
#  16  HouseStyle     1460 non-null   str
#  17  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# ## Statistical Summary of the data

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train_df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# ### Columns with Missing Values

# %%
missing=train_df.isnull().sum()
missing=missing[missing>0]
missing
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
train_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Correlation
# ### Finding Correlation of the features(numerical) with target feature[Saleprice]

# %%
numeric_df=train_df.select_dtypes(include=np.number)
corr=numeric_df.corr()["SalePrice"].sort_values(ascending=False)
print(corr)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# ...

# %%
num_df=train_df.select_dtypes(include=np.number)
corr1=num_df.corr()["SalePrice"]
corr.abs().sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# GarageYrBlt      0.486362
# MasVnrArea       0.477493
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# LotFrontage      0.351799
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# BedroomAbvGr     0.168213
# KitchenAbvGr     0.135907
# EnclosedPorch    0.128578
# ScreenPorch      0.111447
# PoolArea         0.092404
# MSSubClass       0.084284
# OverallCond      0.077856
# MoSold           0.046432
# 3SsnPorch        0.044584
# YrSold           0.028923
# LowQualFinSF     0.025606
# Id               0.021917
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
sns.histplot(train_df["SalePrice"],kde=True)
plt.show()

# %% [markdown]
# ### Checking the skewness of the target variable

# %%
train_df["SalePrice"].skew()
# Out:
# np.float64(1.8828757597682129)

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.boxplot(data=train_df,x="OverallQual",y="SalePrice")
plt.show()

# %%
train_df["GrLivArea"].dtype
# Out:
# dtype('int64')

# %%
sns.regplot(data=train_df,x="GrLivArea",y="SalePrice")
plt.show()

# %%
train_df["GarageCars"]
# Out:
# 0       2
# 1       2
# 2       2
# 3       3
# 4       3
#        ..
# 1455    2
# 1456    2
# 1457    1
# 1458    1
# 1459    1
# Name: GarageCars, Length: 1460, dtype: int64

# %%
sns.boxplot(data=train_df,x="GarageCars",y="SalePrice")
plt.show()

# %%
sns.regplot(data=train_df,x="GarageArea",y="SalePrice")
plt.show()

# %%
train_df["TotalBsmtSF"]
# Out:
# 0        856
# 1       1262
# 2        920
# 3        756
# 4       1145
#         ...
# 1455     953
# 1456    1542
# 1457    1152
# 1458    1078
# 1459    1256
# Name: TotalBsmtSF, Length: 1460, dtype: int64

# %%
sns.scatterplot(data=train_df,x="TotalBsmtSF",y="SalePrice")
plt.show()

# %%
sns.boxplot(data=train_df,x="Fireplaces",y="SalePrice")
plt.show()

# %%
sns.regplot(data=train_df,x="LotArea",y="SalePrice")
plt.show()

# %%
sns.regplot(data=train_df,x="LotFrontage",y="SalePrice")
plt.show()

# %%
cat_col=train_df.select_dtypes(include="object").columns
# Out:
# C:\Users\mraj7\AppData\Local\Temp\ipykernel_15668\2916041297.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_col=train_df.select_dtypes(include="object").columns

# %%
train_df[cat_col].nunique().sort_values(ascending=False)
# Out:
# Neighborhood     25
# Exterior2nd      16
# Exterior1st      15
# Condition1        9
# SaleType          9
# HouseStyle        8
# RoofMatl          8
# Condition2        8
# Functional        7
# BsmtFinType2      6
# RoofStyle         6
# BsmtFinType1      6
# SaleCondition     6
# Heating           6
# Foundation        6
# GarageType        6
# ExterCond         5
# LotConfig         5
# MSZoning          5
# GarageCond        5
# GarageQual        5
# HeatingQC         5
# Electrical        5
# BldgType          5
# FireplaceQu       5
# LandContour       4
# LotShape          4
# KitchenQual       4
# MiscFeature       4
# Fence             4
# BsmtCond          4
# ExterQual         4
# BsmtExposure      4
# BsmtQual          4
# LandSlope         3
# PoolQC            3
# GarageFinish      3
# PavedDrive        3
# MasVnrType        3
# Utilities         2
# Alley             2
# Street            2
# CentralAir        2
# dtype: int64

# %%
sns.boxplot(data=train_df,x="Exterior2nd",y="SalePrice")
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(data=train_df,x="Neighborhood",y="SalePrice")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Feature Engineering
# ### Step1 Handling Missing Values

# %%
train_df["LotFrontage"]
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
train_df["LotFrontage"]=train_df.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))

# %%
test_df["LotFrontage"].isnull().sum()
# Out:
# np.int64(227)

# %%
test_df["LotFrontage"]=test_df.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))

# %%
test_df["LotFrontage"].isnull().sum()
# Out:
# np.int64(0)

# %%
train_df["LotFrontage"].isnull().sum()
# Out:
# np.int64(0)

# %%
train_df["Alley"]
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1455    NaN
# 1456    NaN
# 1457    NaN
# 1458    NaN
# 1459    NaN
# Name: Alley, Length: 1460, dtype: str

# %%
train_df["Alley"]=train_df["Alley"].fillna("NoAlley")

# %%
train_df["Alley"].isnull().sum()
# Out:
# np.int64(0)

# %%
train_df["Alley"].unique()
# Out:
# <StringArray>
# ['NoAlley', 'Grvl', 'Pave']
# Length: 3, dtype: str

# %%
test_df.shape
# Out:
# (1459, 80)

# %%
test_df["Alley"].isnull().sum()
# Out:
# np.int64(1352)

# %%
test_df["Alley"].unique()
# Out:
# <StringArray>
# [nan, 'Pave', 'Grvl']
# Length: 3, dtype: str

# %%
test_df["Alley"]=test_df["Alley"].fillna("NOAlley")

# %%
test_df["Alley"].isnull().sum()
# Out:
# np.int64(0)

# %%
train_df["PoolQC"]=train_df["PoolQC"].fillna("NOPOOL")

# %%
train_df["PoolQC"].unique()
# Out:
# <StringArray>
# ['NOPOOL', 'Ex', 'Fa', 'Gd']
# Length: 4, dtype: str

# %%
train_df["PoolQC"].isnull().sum()
# Out:
# np.int64(0)

# %%
test_df["PoolQC"].unique()
# Out:
# <StringArray>
# [nan, 'Ex', 'Gd']
# Length: 3, dtype: str

# %%
test_df["PoolQC"]=test_df["PoolQC"].fillna("NoPooL")

# %%
test_df["PoolQC"].unique()
# Out:
# <StringArray>
# ['NoPooL', 'Ex', 'Gd']
# Length: 3, dtype: str

# %%
train_df["MiscFeature"]=train_df["MiscFeature"].fillna("NoFeature")

# %%
train_df["MiscFeature"].isnull().sum()
# Out:
# np.int64(0)

# %%
test_df["MiscFeature"].isnull().sum()
# Out:
# np.int64(1408)

# %%
test_df["MiscFeature"].unique()
# Out:
# <StringArray>
# [nan, 'Gar2', 'Shed', 'Othr']
# Length: 4, dtype: str

# %%
test_df["MiscFeature"]=test_df["MiscFeature"].fillna("NoFeature")

# %%
train_df["Fence"]=train_df["Fence"].fillna("NoFence")

# %%
train_df["Fence"].isnull().sum()
# Out:
# np.int64(0)

# %%
train_df["Fence"].unique()
# Out:
# <StringArray>
# ['NoFence', 'MnPrv', 'GdWo', 'GdPrv', 'MnWw']
# Length: 5, dtype: str

# %%
test_df["Fence"].unique()
# Out:
# <StringArray>
# ['MnPrv', nan, 'GdPrv', 'GdWo', 'MnWw']
# Length: 5, dtype: str

# %%
test_df["Fence"]=test_df["Fence"].fillna("NoFence")

# %%
train_df["FireplaceQu"]=train_df["FireplaceQu"].fillna("NO FirePlace")

# %%
train_df["FireplaceQu"].isnull().sum()
# Out:
# np.int64(0)

# %%
train_df["FireplaceQu"]
# Out:
# 0       NO FirePlace
# 1                 TA
# 2                 TA
# 3                 Gd
# 4                 TA
#             ...
# 1455              TA
# 1456              TA
# 1457              Gd
# 1458    NO FirePlace
# 1459    NO FirePlace
# Name: FireplaceQu, Length: 1460, dtype: str

# %%
train_df["FireplaceQu"].unique()
# Out:
# <StringArray>
# ['NO FirePlace', 'TA', 'Gd', 'Fa', 'Ex', 'Po']
# Length: 6, dtype: str

# %%
test_df["FireplaceQu"].unique()
# Out:
# <StringArray>
# [nan, 'TA', 'Gd', 'Po', 'Fa', 'Ex']
# Length: 6, dtype: str

# %%
test_df["FireplaceQu"]=test_df["FireplaceQu"].fillna("NO FirePlace")

# %%
train_df["MasVnrType"]
# Out:
# 0       BrkFace
# 1           NaN
# 2       BrkFace
# 3           NaN
# 4       BrkFace
#          ...
# 1455        NaN
# 1456      Stone
# 1457        NaN
# 1458        NaN
# 1459        NaN
# Name: MasVnrType, Length: 1460, dtype: str

# %%
train_df["MasVnrType"]=train_df["MasVnrType"].fillna("None")

# %%
train_df["MasVnrArea"]=train_df["MasVnrArea"].fillna(0)

# %%
test_df["MasVnrArea"].isnull().sum()
# Out:
# np.int64(15)

# %%
test_df["MasVnrArea"]=test_df["MasVnrArea"].fillna(0)

# %%
train_df["BsmtQual"].unique()
# Out:
# <StringArray>
# ['Gd', 'TA', 'Ex', nan, 'Fa']
# Length: 5, dtype: str

# %%
train_df["BsmtQual"]=train_df["BsmtQual"].fillna("No Basement")

# %%
test_df["BsmtQual"].unique()
# Out:
# <StringArray>
# ['TA', 'Gd', 'Ex', 'Fa', nan]
# Length: 5, dtype: str

# %%
test_df["BsmtQual"]=test_df["BsmtQual"].fillna("No Basement")

# %%
train_df["BsmtCond"].unique()
# Out:
# <StringArray>
# ['TA', 'Gd', nan, 'Fa', 'Po']
# Length: 5, dtype: str

# %%
train_df["BsmtCond"]=train_df["BsmtCond"].fillna("No Basement")

# %%
test_df["BsmtCond"].unique()
# Out:
# <StringArray>
# ['TA', 'Po', 'Fa', 'Gd', nan]
# Length: 5, dtype: str

# %%
test_df["BsmtCond"]=test_df["BsmtCond"].fillna("No Basement")

# %%
train_df["BsmtExposure"].unique()
# Out:
# <StringArray>
# ['No', 'Gd', 'Mn', 'Av', nan]
# Length: 5, dtype: str

# %%
train_df["BsmtExposure"]=train_df["BsmtExposure"].fillna("BsmtExposure")

# %%
test_df["BsmtExposure"].unique()
# Out:
# <StringArray>
# ['No', 'Gd', 'Mn', 'Av', nan]
# Length: 5, dtype: str

# %%
test_df["BsmtExposure"]=test_df["BsmtExposure"].fillna("BsmtExposure")

# %%
train_df["BsmtFinType1"]=train_df["BsmtFinType1"].fillna("No Basement")

# %%
test_df["BsmtFinType1"].unique()
# Out:
# <StringArray>
# ['Rec', 'ALQ', 'GLQ', 'Unf', 'BLQ', 'LwQ', nan]
# Length: 7, dtype: str

# %%
test_df["BsmtFinType1"]=test_df["BsmtFinType1"].fillna("BsmtFinType1")

# %%
train_df["BsmtFinType2"]=train_df["BsmtFinType2"].fillna("No Basement")

# %%
test_df["BsmtFinType2"].unique()
# Out:
# <StringArray>
# ['LwQ', 'Unf', 'Rec', 'BLQ', 'GLQ', 'ALQ', nan]
# Length: 7, dtype: str

# %%
test_df["BsmtFinType2"]=test_df["BsmtFinType2"].fillna("No Basement")

# %%
train_df["Electrical"].unique()
# Out:
# <StringArray>
# ['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan]
# Length: 6, dtype: str

# %%
train_df["Electrical"].value_counts(dropna=False)
# Out:
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# NaN         1
# Name: count, dtype: int64

# %%
train_df["Electrical"]=train_df["Electrical"].fillna("SBrkr")

# %%
test_df["Electrical"].unique()
# Out:
# <StringArray>
# ['SBrkr', 'FuseA', 'FuseF', 'FuseP']
# Length: 4, dtype: str

# %%
train_df["GarageType"].unique()
# Out:
# <StringArray>
# ['Attchd', 'Detchd', 'BuiltIn', 'CarPort', nan, 'Basment', '2Types']
# Length: 7, dtype: str

# %%
train_df["GarageType"]=train_df["GarageType"].fillna("No Garage")

# %%
test_df["GarageType"].unique()
# Out:
# <StringArray>
# ['Attchd', 'Detchd', 'BuiltIn', nan, 'Basment', '2Types', 'CarPort']
# Length: 7, dtype: str

# %%
test_df["GarageType"]=test_df["GarageType"].fillna("No Garage")

# %%
train_df["GarageFinish"].unique()
# Out:
# <StringArray>
# ['RFn', 'Unf', 'Fin', nan]
# Length: 4, dtype: str

# %%
train_df["GarageFinish"]=train_df["GarageFinish"].fillna("No Garage")

# %%
test_df["GarageFinish"].unique()
# Out:
# <StringArray>
# ['Unf', 'Fin', 'RFn', nan]
# Length: 4, dtype: str

# %%
test_df["GarageFinish"]=test_df["GarageFinish"].fillna("No Garage")

# %%
train_df["GarageCond"]=train_df["GarageCond"].fillna("No Garage")

# %%
test_df["GarageCond"]=test_df["GarageCond"].fillna("No Garage")

# %%
train_df["GarageQual"].unique()
# Out:
# <StringArray>
# ['TA', 'Fa', 'Gd', nan, 'Ex', 'Po']
# Length: 6, dtype: str

# %%
train_df["GarageQual"]=train_df["GarageQual"].fillna("No Garage")

# %%
test_df["GarageQual"]=test_df["GarageQual"].fillna("No Garage")

# %%
train_df["GarageYrBlt"]
# Out:
# 0       2003.0
# 1       1976.0
# 2       2001.0
# 3       1998.0
# 4       2000.0
#          ...
# 1455    1999.0
# 1456    1978.0
# 1457    1941.0
# 1458    1950.0
# 1459    1965.0
# Name: GarageYrBlt, Length: 1460, dtype: float64

# %%
train_df["GarageYrBlt"]=train_df["GarageYrBlt"].fillna(0)

# %%
test_df["GarageYrBlt"]=test_df["GarageYrBlt"].fillna(0)

# %% [markdown]
# ## Removing outliers

# %%
#GrLivArea
train_df=train_df.drop(
    train_df[(train_df["GrLivArea"]>4000) & (train_df["SalePrice"]<300000)
             ].index
)

# %%
sns.regplot(data=train_df,x="GrLivArea",y="SalePrice")
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
train_df["SalePrice"]=np.log1p(train_df["SalePrice"])

# %%
sns.histplot(data=train_df,x="SalePrice")
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %% [markdown]
# ## Handling the Remaining Skwed Numerical Features

# %%
numerical_feature=train_df.select_dtypes(include=["int64","float64"]).columns.drop("SalePrice")

# %%
skweness=train_df[numerical_feature].skew().sort_values(ascending=False)

# %%
print(skweness)
# Out:
# MiscVal          24.460085
# PoolArea         15.948945
# LotArea          12.573925
# 3SsnPorch        10.297106
# LowQualFinSF      9.004955
# KitchenAbvGr      4.484883
# BsmtFinSF2        4.251925
# ScreenPorch       4.118929
# BsmtHalfBath      4.100114
# EnclosedPorch     3.087164
# MasVnrArea        2.696329
# OpenPorchSF       2.339829
# LotFrontage       1.547767
# WoodDeckSF        1.545805
# MSSubClass        1.407011
# GrLivArea         1.010992
# BsmtUnfSF         0.920903
# 1stFlrSF          0.887637
# 2ndFlrSF          0.812957
# BsmtFinSF1        0.764789
# OverallCond       0.691035
# HalfBath          0.680051
# TotRmsAbvGrd      0.660502
# Fireplaces        0.632060
# BsmtFullBath      0.590358
# TotalBsmtSF       0.511703
# MoSold            0.215432
# BedroomAbvGr      0.212325
# OverallQual       0.200786
# GarageArea        0.131748
# YrSold            0.095420
# FullBath          0.031271
# Id                0.000165
# GarageCars       -0.342377
# ...

# %%
skwedfeat=skweness[skweness>0.75]

# %%
skwedfeat
# Out:
# MiscVal          24.460085
# PoolArea         15.948945
# LotArea          12.573925
# 3SsnPorch        10.297106
# LowQualFinSF      9.004955
# KitchenAbvGr      4.484883
# BsmtFinSF2        4.251925
# ScreenPorch       4.118929
# BsmtHalfBath      4.100114
# EnclosedPorch     3.087164
# MasVnrArea        2.696329
# OpenPorchSF       2.339829
# LotFrontage       1.547767
# WoodDeckSF        1.545805
# MSSubClass        1.407011
# GrLivArea         1.010992
# BsmtUnfSF         0.920903
# 1stFlrSF          0.887637
# 2ndFlrSF          0.812957
# BsmtFinSF1        0.764789
# dtype: float64

# %%
skwedfeat
# Out:
# Index(['MiscVal', 'PoolArea', 'LotArea', '3SsnPorch', 'LowQualFinSF',
#        'KitchenAbvGr', 'BsmtFinSF2', 'ScreenPorch', 'BsmtHalfBath',
#        'EnclosedPorch', 'MasVnrArea', 'OpenPorchSF', 'LotFrontage',
#        'WoodDeckSF', 'MSSubClass', 'GrLivArea', 'BsmtUnfSF', '1stFlrSF',
#        '2ndFlrSF', 'BsmtFinSF1'],
#       dtype='str')

# %%
train_df[skwedfeat]=np.log1p(train_df[skwedfeat])

# %%
test_df[skwedfeat]=np.log1p(test_df[skwedfeat])

# %% [markdown]
# ## Creating New Features

# %%
train_df["TotalSF"]=(
    train_df["TotalBsmtSF"]+
    train_df["1stFlrSF"]+
    train_df["2ndFlrSF"]
)

# %%
test_df["TotalSF"]=(
    test_df["TotalBsmtSF"]+
    test_df["1stFlrSF"]+
    test_df["2ndFlrSF"]
)

# %%
train_df["HouseAge"]=(
    train_df["YrSold"]-
    train_df["YearBuilt"]
)

# %%
test_df["HouseAge"]=(
    test_df["YrSold"]-
    test_df["YearBuilt"]

)

# %% [markdown]
# ### Converting Categorical Features to Numerical using One-Hot Encoding

# %%
print(f"\nshape before get dummies: {train_df.shape}")
# Out:
# shape before get dummies: (1458, 81)

# %%
train_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
y=train_df["SalePrice"]

# %%
all_data=pd.concat([train_df.drop(columns=["SalePrice"]),test_df],ignore_index=True)

# %%
all_dat=pd.get_dummies(all_data)

# %%
print(f"Shape After getting dummies: {all_dat.shape}")
print(f"Feature Enginering Complete")
# Out:
# Shape After getting dummies: (2917, 308)
# Feature Enginering Complete

# %%
x_train=all_dat[:train_df.shape[0]]

# %%
x_test=all_dat[train_df.shape[0]:]

# %%
x_train.shape
# Out:
# (1458, 308)

# %%
x_test.shape
# Out:
# (1459, 308)

# %%
x_train.to_csv(r"C:\Users\mraj7\Desktop\AI_ML_Projeccts\House_Prices\Data\x_train_processing.csv",index=False)

# %%
x_test.to_csv(r"C:\Users\mraj7\Desktop\AI_ML_Projeccts\House_Prices\Data\x_test_processing.csv",index=False)

# %%
y.to_csv(r"C:\Users\mraj7\Desktop\AI_ML_Projeccts\House_Prices\Data\target_processed.csv",index=False)

# %%
import os

path = r"C:\Users\mraj7\Desktop\AI_ML_Projeccts\House_Prices\Data\x_train_processed.csv"

print(os.path.exists(path))
# Out:
# True
